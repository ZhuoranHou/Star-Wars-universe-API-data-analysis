# %% [markdown]
# ## HW5
# ### Zhuoran Hou zh105
# Using the requests library, download all the people in the Star Wars universe using the Star Wars API (https://swapi.dev/documentation). Show the name of the oldest person (or robot or alien) and list the titles of all the films they appeared in. Blog.

# %% [markdown]
# ### 1. Download Star Wars universe database

# %%
import requests
import numpy as np
import pandas as pd
import os
import json

# %%
base_url = 'http://swapi.dev/api/'

# %%
i = 1
urls=[]

while(True):
    urls.append(os.path.join(base_url, f'people/{i}'))
    if requests.get(os.path.join(base_url, f'people/{i+1}')).json() == {'detail': 'Not found'}:
        i +=1
        if requests.get(os.path.join(base_url, f'people/{i+1}')).json() == {'detail': 'Not found'}:
            break
    
    i +=1

# %%
len(urls)
# Out:
# 82

# %%
people = [requests.get(url).json() for url in urls]

# %%
people
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/14/',
#    'http://swapi.dev/api/vehicles/30/'],
#   'starships': ['http://swapi.dev/api/starships/12/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'http://swapi.dev/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:10:51.357000Z',
#   'edited': '2014-12-20T21:17:50.309000Z',
#   'url': 'http://swapi.dev/api/people/2/'},
#  {'name': 'R2-D2',
#   'height': '96',
#   'mass': '32',
#   'hair_color': 'n/a',
#   'skin_color': 'white, blue',
#   'eye_color': 'red',
#   'birth_year': '33BBY',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:11:50.376000Z',
#   'edited': '2014-12-20T21:17:50.311000Z',
#   'url': 'http://swapi.dev/api/people/3/'},
#  {'name': 'Darth Vader',
#   'height': '202',
#   'mass': '136',
#   'hair_color': 'none',
#   'skin_color': 'white',
#   'eye_color': 'yellow',
#   'birth_year': '41.9BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/13/'],
#   'created': '2014-12-10T15:18:20.704000Z',
#   'edited': '2014-12-20T21:17:50.313000Z',
#   'url': 'http://swapi.dev/api/people/4/'},
#  {'name': 'Leia Organa',
#   'height': '150',
#   'mass': '49',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '19BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/30/'],
#   'starships': [],
#   'created': '2014-12-10T15:20:09.791000Z',
#   'edited': '2014-12-20T21:17:50.315000Z',
#   'url': 'http://swapi.dev/api/people/5/'},
#  {'name': 'Owen Lars',
#   'height': '178',
#   'mass': '120',
#   'hair_color': 'brown, grey',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '52BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:52:14.024000Z',
#   'edited': '2014-12-20T21:17:50.317000Z',
#   'url': 'http://swapi.dev/api/people/6/'},
#  {'name': 'Beru Whitesun lars',
#   'height': '165',
#   'mass': '75',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '47BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:53:41.121000Z',
#   'edited': '2014-12-20T21:17:50.319000Z',
#   'url': 'http://swapi.dev/api/people/7/'},
#  {'name': 'R5-D4',
#   'height': '97',
#   'mass': '32',
#   'hair_color': 'n/a',
#   'skin_color': 'white, red',
#   'eye_color': 'red',
#   'birth_year': 'unknown',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/'],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:57:50.959000Z',
#   'edited': '2014-12-20T21:17:50.321000Z',
#   'url': 'http://swapi.dev/api/people/8/'},
#  {'name': 'Biggs Darklighter',
#   'height': '183',
#   'mass': '84',
#   'hair_color': 'black',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '24BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/1/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-10T15:59:50.509000Z',
#   'edited': '2014-12-20T21:17:50.323000Z',
#   'url': 'http://swapi.dev/api/people/9/'},
#  {'name': 'Obi-Wan Kenobi',
#   'height': '182',
#   'mass': '77',
#   'hair_color': 'auburn, white',
#   'skin_color': 'fair',
#   'eye_color': 'blue-gray',
#   'birth_year': '57BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/20/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/38/'],
#   'starships': ['http://swapi.dev/api/starships/48/',
#    'http://swapi.dev/api/starships/59/',
#    'http://swapi.dev/api/starships/64/',
#    'http://swapi.dev/api/starships/65/',
#    'http://swapi.dev/api/starships/74/'],
#   'created': '2014-12-10T16:16:29.192000Z',
#   'edited': '2014-12-20T21:17:50.325000Z',
#   'url': 'http://swapi.dev/api/people/10/'},
#  {'name': 'Anakin Skywalker',
#   'height': '188',
#   'mass': '84',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '41.9BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/44/',
#    'http://swapi.dev/api/vehicles/46/'],
#   'starships': ['http://swapi.dev/api/starships/39/',
#    'http://swapi.dev/api/starships/59/',
#    'http://swapi.dev/api/starships/65/'],
#   'created': '2014-12-10T16:20:44.310000Z',
#   'edited': '2014-12-20T21:17:50.327000Z',
#   'url': 'http://swapi.dev/api/people/11/'},
#  {'name': 'Wilhuff Tarkin',
#   'height': '180',
#   'mass': 'unknown',
#   'hair_color': 'auburn, grey',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '64BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/21/',
#   'films': ['http://swapi.dev/api/films/1/', 'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T16:26:56.138000Z',
#   'edited': '2014-12-20T21:17:50.330000Z',
#   'url': 'http://swapi.dev/api/people/12/'},
#  {'name': 'Chewbacca',
#   'height': '228',
#   'mass': '112',
#   'hair_color': 'brown',
#   'skin_color': 'unknown',
#   'eye_color': 'blue',
#   'birth_year': '200BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/14/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/3/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/19/'],
#   'starships': ['http://swapi.dev/api/starships/10/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-10T16:42:45.066000Z',
#   'edited': '2014-12-20T21:17:50.332000Z',
#   'url': 'http://swapi.dev/api/people/13/'},
#  {'name': 'Han Solo',
#   'height': '180',
#   'mass': '80',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '29BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/22/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-10T16:49:14.582000Z',
#   'edited': '2014-12-20T21:17:50.334000Z',
#   'url': 'http://swapi.dev/api/people/14/'},
#  {'name': 'Greedo',
#   'height': '173',
#   'mass': '74',
#   'hair_color': 'n/a',
#   'skin_color': 'green',
#   'eye_color': 'black',
#   'birth_year': '44BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/23/',
#   'films': ['http://swapi.dev/api/films/1/'],
#   'species': ['http://swapi.dev/api/species/4/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T17:03:30.334000Z',
#   'edited': '2014-12-20T21:17:50.336000Z',
#   'url': 'http://swapi.dev/api/people/15/'},
#  {'name': 'Jabba Desilijic Tiure',
#   'height': '175',
#   'mass': '1,358',
#   'hair_color': 'n/a',
#   'skin_color': 'green-tan, brown',
#   'eye_color': 'orange',
#   'birth_year': '600BBY',
#   'gender': 'hermaphrodite',
#   'homeworld': 'http://swapi.dev/api/planets/24/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/5/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T17:11:31.638000Z',
#   'edited': '2014-12-20T21:17:50.338000Z',
#   'url': 'http://swapi.dev/api/people/16/'},
#  {'name': 'Wedge Antilles',
#   'height': '170',
#   'mass': '77',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'hazel',
#   'birth_year': '21BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/22/',
#   'films': ['http://swapi.dev/api/films/1/',
#    'http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/14/'],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-12T11:08:06.469000Z',
#   'edited': '2014-12-20T21:17:50.341000Z',
#   'url': 'http://swapi.dev/api/people/18/'},
#  {'name': 'Jek Tono Porkins',
#   'height': '180',
#   'mass': '110',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/26/',
#   'films': ['http://swapi.dev/api/films/1/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-12T11:16:56.569000Z',
#   'edited': '2014-12-20T21:17:50.343000Z',
#   'url': 'http://swapi.dev/api/people/19/'},
#  {'name': 'Yoda',
#   'height': '66',
#   'mass': '17',
#   'hair_color': 'white',
#   'skin_color': 'green',
#   'eye_color': 'brown',
#   'birth_year': '896BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': ['http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/6/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:26:01.042000Z',
#   'edited': '2014-12-20T21:17:50.345000Z',
#   'url': 'http://swapi.dev/api/people/20/'},
#  {'name': 'Palpatine',
#   'height': '170',
#   'mass': '75',
#   'hair_color': 'grey',
#   'skin_color': 'pale',
#   'eye_color': 'yellow',
#   'birth_year': '82BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:48:05.971000Z',
#   'edited': '2014-12-20T21:17:50.347000Z',
#   'url': 'http://swapi.dev/api/people/21/'},
#  {'name': 'Boba Fett',
#   'height': '183',
#   'mass': '78.2',
#   'hair_color': 'black',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '31.5BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': ['http://swapi.dev/api/films/2/',
#    'http://swapi.dev/api/films/3/',
#    'http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/21/'],
#   'created': '2014-12-15T12:49:32.457000Z',
#   'edited': '2014-12-20T21:17:50.349000Z',
#   'url': 'http://swapi.dev/api/people/22/'},
#  {'name': 'IG-88',
#   'height': '200',
#   'mass': '140',
#   'hair_color': 'none',
#   'skin_color': 'metal',
#   'eye_color': 'red',
#   'birth_year': '15BBY',
#   'gender': 'none',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': ['http://swapi.dev/api/films/2/'],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:51:10.076000Z',
#   'edited': '2014-12-20T21:17:50.351000Z',
#   'url': 'http://swapi.dev/api/people/23/'},
#  {'name': 'Bossk',
#   'height': '190',
#   'mass': '113',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'red',
#   'birth_year': '53BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/29/',
#   'films': ['http://swapi.dev/api/films/2/'],
#   'species': ['http://swapi.dev/api/species/7/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:53:49.297000Z',
#   'edited': '2014-12-20T21:17:50.355000Z',
#   'url': 'http://swapi.dev/api/people/24/'},
#  {'name': 'Lando Calrissian',
#   'height': '177',
#   'mass': '79',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '31BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/30/',
#   'films': ['http://swapi.dev/api/films/2/', 'http://swapi.dev/api/films/3/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/'],
#   'created': '2014-12-15T12:56:32.683000Z',
#   'edited': '2014-12-20T21:17:50.357000Z',
#   'url': 'http://swapi.dev/api/people/25/'},
#  {'name': 'Lobot',
#   'height': '175',
#   'mass': '79',
#   'hair_color': 'none',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '37BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/6/',
#   'films': ['http://swapi.dev/api/films/2/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T13:01:57.178000Z',
#   'edited': '2014-12-20T21:17:50.359000Z',
#   'url': 'http://swapi.dev/api/people/26/'},
#  {'name': 'Ackbar',
#   'height': '180',
#   'mass': '83',
#   'hair_color': 'none',
#   'skin_color': 'brown mottle',
#   'eye_color': 'orange',
#   'birth_year': '41BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/31/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': ['http://swapi.dev/api/species/8/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:07:50.584000Z',
#   'edited': '2014-12-20T21:17:50.362000Z',
#   'url': 'http://swapi.dev/api/people/27/'},
#  {'name': 'Mon Mothma',
#   'height': '150',
#   'mass': 'unknown',
#   'hair_color': 'auburn',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '48BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/32/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:12:38.895000Z',
#   'edited': '2014-12-20T21:17:50.364000Z',
#   'url': 'http://swapi.dev/api/people/28/'},
#  {'name': 'Arvel Crynyd',
#   'height': 'unknown',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/28/'],
#   'created': '2014-12-18T11:16:33.020000Z',
#   'edited': '2014-12-20T21:17:50.367000Z',
#   'url': 'http://swapi.dev/api/people/29/'},
#  {'name': 'Wicket Systri Warrick',
#   'height': '88',
#   'mass': '20',
#   'hair_color': 'brown',
#   'skin_color': 'brown',
#   'eye_color': 'brown',
#   'birth_year': '8BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/7/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': ['http://swapi.dev/api/species/9/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:21:58.954000Z',
#   'edited': '2014-12-20T21:17:50.369000Z',
#   'url': 'http://swapi.dev/api/people/30/'},
#  {'name': 'Nien Nunb',
#   'height': '160',
#   'mass': '68',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/33/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': ['http://swapi.dev/api/species/10/'],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/'],
#   'created': '2014-12-18T11:26:18.541000Z',
#   'edited': '2014-12-20T21:17:50.371000Z',
#   'url': 'http://swapi.dev/api/people/31/'},
#  {'name': 'Qui-Gon Jinn',
#   'height': '193',
#   'mass': '89',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '92BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/38/'],
#   'starships': [],
#   'created': '2014-12-19T16:54:53.618000Z',
#   'edited': '2014-12-20T21:17:50.375000Z',
#   'url': 'http://swapi.dev/api/people/32/'},
#  {'name': 'Nute Gunray',
#   'height': '191',
#   'mass': '90',
#   'hair_color': 'none',
#   'skin_color': 'mottled green',
#   'eye_color': 'red',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/18/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/11/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:05:57.357000Z',
#   'edited': '2014-12-20T21:17:50.377000Z',
#   'url': 'http://swapi.dev/api/people/33/'},
#  {'name': 'Finis Valorum',
#   'height': '170',
#   'mass': 'unknown',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '91BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:21:45.915000Z',
#   'edited': '2014-12-20T21:17:50.379000Z',
#   'url': 'http://swapi.dev/api/people/34/'},
#  {'name': 'Padmé Amidala',
#   'height': '185',
#   'mass': '45',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '46BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/39/',
#    'http://swapi.dev/api/starships/49/',
#    'http://swapi.dev/api/starships/64/'],
#   'created': '2014-12-19T17:28:26.926000Z',
#   'edited': '2014-12-20T21:17:50.381000Z',
#   'url': 'http://swapi.dev/api/people/35/'},
#  {'name': 'Jar Jar Binks',
#   'height': '196',
#   'mass': '66',
#   'hair_color': 'none',
#   'skin_color': 'orange',
#   'eye_color': 'orange',
#   'birth_year': '52BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:29:32.489000Z',
#   'edited': '2014-12-20T21:17:50.383000Z',
#   'url': 'http://swapi.dev/api/people/36/'},
#  {'name': 'Roos Tarpals',
#   'height': '224',
#   'mass': '82',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:32:56.741000Z',
#   'edited': '2014-12-20T21:17:50.385000Z',
#   'url': 'http://swapi.dev/api/people/37/'},
#  {'name': 'Rugor Nass',
#   'height': '206',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:33:38.909000Z',
#   'edited': '2014-12-20T21:17:50.388000Z',
#   'url': 'http://swapi.dev/api/people/38/'},
#  {'name': 'Ric Olié',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/40/'],
#   'created': '2014-12-19T17:45:01.522000Z',
#   'edited': '2014-12-20T21:17:50.392000Z',
#   'url': 'http://swapi.dev/api/people/39/'},
#  {'name': 'Watto',
#   'height': '137',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'blue, grey',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/34/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/13/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:48:54.647000Z',
#   'edited': '2014-12-20T21:17:50.395000Z',
#   'url': 'http://swapi.dev/api/people/40/'},
#  {'name': 'Sebulba',
#   'height': '112',
#   'mass': '40',
#   'hair_color': 'none',
#   'skin_color': 'grey, red',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/35/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/14/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:53:02.586000Z',
#   'edited': '2014-12-20T21:17:50.397000Z',
#   'url': 'http://swapi.dev/api/people/41/'},
#  {'name': 'Quarsh Panaka',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '62BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:55:43.348000Z',
#   'edited': '2014-12-20T21:17:50.399000Z',
#   'url': 'http://swapi.dev/api/people/42/'},
#  {'name': 'Shmi Skywalker',
#   'height': '163',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '72BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:57:41.191000Z',
#   'edited': '2014-12-20T21:17:50.401000Z',
#   'url': 'http://swapi.dev/api/people/43/'},
#  {'name': 'Darth Maul',
#   'height': '175',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'red',
#   'eye_color': 'yellow',
#   'birth_year': '54BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/36/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/22/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/42/'],
#   'starships': ['http://swapi.dev/api/starships/41/'],
#   'created': '2014-12-19T18:00:41.929000Z',
#   'edited': '2014-12-20T21:17:50.403000Z',
#   'url': 'http://swapi.dev/api/people/44/'},
#  {'name': 'Bib Fortuna',
#   'height': '180',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'pink',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/37/',
#   'films': ['http://swapi.dev/api/films/3/'],
#   'species': ['http://swapi.dev/api/species/15/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:47:02.512000Z',
#   'edited': '2014-12-20T21:17:50.407000Z',
#   'url': 'http://swapi.dev/api/people/45/'},
#  {'name': 'Ayla Secura',
#   'height': '178',
#   'mass': '55',
#   'hair_color': 'none',
#   'skin_color': 'blue',
#   'eye_color': 'hazel',
#   'birth_year': '48BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/37/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/15/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:48:01.172000Z',
#   'edited': '2014-12-20T21:17:50.409000Z',
#   'url': 'http://swapi.dev/api/people/46/'},
#  {'name': 'Ratts Tyerel',
#   'height': '79',
#   'mass': '15',
#   'hair_color': 'none',
#   'skin_color': 'grey, blue',
#   'eye_color': 'unknown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/38/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/16/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:53:15.086000Z',
#   'edited': '2014-12-20T21:17:50.410000Z',
#   'url': 'http://swapi.dev/api/people/47/'},
#  {'name': 'Dud Bolt',
#   'height': '94',
#   'mass': '45',
#   'hair_color': 'none',
#   'skin_color': 'blue, grey',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/39/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/17/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:57:31.858000Z',
#   'edited': '2014-12-20T21:17:50.414000Z',
#   'url': 'http://swapi.dev/api/people/48/'},
#  {'name': 'Gasgano',
#   'height': '122',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'white, blue',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/40/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/18/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:02:12.223000Z',
#   'edited': '2014-12-20T21:17:50.416000Z',
#   'url': 'http://swapi.dev/api/people/49/'},
#  {'name': 'Ben Quadinaros',
#   'height': '163',
#   'mass': '65',
#   'hair_color': 'none',
#   'skin_color': 'grey, green, yellow',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/41/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/19/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:08:33.777000Z',
#   'edited': '2014-12-20T21:17:50.417000Z',
#   'url': 'http://swapi.dev/api/people/50/'},
#  {'name': 'Mace Windu',
#   'height': '188',
#   'mass': '84',
#   'hair_color': 'none',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '72BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/42/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:12:30.846000Z',
#   'edited': '2014-12-20T21:17:50.420000Z',
#   'url': 'http://swapi.dev/api/people/51/'},
#  {'name': 'Ki-Adi-Mundi',
#   'height': '198',
#   'mass': '82',
#   'hair_color': 'white',
#   'skin_color': 'pale',
#   'eye_color': 'yellow',
#   'birth_year': '92BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/43/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/20/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:15:32.293000Z',
#   'edited': '2014-12-20T21:17:50.422000Z',
#   'url': 'http://swapi.dev/api/people/52/'},
#  {'name': 'Kit Fisto',
#   'height': '196',
#   'mass': '87',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/44/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/21/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:18:57.202000Z',
#   'edited': '2014-12-20T21:17:50.424000Z',
#   'url': 'http://swapi.dev/api/people/53/'},
#  {'name': 'Eeth Koth',
#   'height': '171',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'brown',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/45/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/22/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:26:47.902000Z',
#   'edited': '2014-12-20T21:17:50.427000Z',
#   'url': 'http://swapi.dev/api/people/54/'},
#  {'name': 'Adi Gallia',
#   'height': '184',
#   'mass': '50',
#   'hair_color': 'none',
#   'skin_color': 'dark',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/23/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:29:11.661000Z',
#   'edited': '2014-12-20T21:17:50.432000Z',
#   'url': 'http://swapi.dev/api/people/55/'},
#  {'name': 'Saesee Tiin',
#   'height': '188',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/47/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/24/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:32:11.669000Z',
#   'edited': '2014-12-20T21:17:50.434000Z',
#   'url': 'http://swapi.dev/api/people/56/'},
#  {'name': 'Yarael Poof',
#   'height': '264',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'white',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/48/',
#   'films': ['http://swapi.dev/api/films/4/'],
#   'species': ['http://swapi.dev/api/species/25/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:34:48.725000Z',
#   'edited': '2014-12-20T21:17:50.437000Z',
#   'url': 'http://swapi.dev/api/people/57/'},
#  {'name': 'Plo Koon',
#   'height': '188',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'orange',
#   'eye_color': 'black',
#   'birth_year': '22BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/49/',
#   'films': ['http://swapi.dev/api/films/4/',
#    'http://swapi.dev/api/films/5/',
#    'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/26/'],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/48/'],
#   'created': '2014-12-20T10:49:19.859000Z',
#   'edited': '2014-12-20T21:17:50.439000Z',
#   'url': 'http://swapi.dev/api/people/58/'},
#  {'name': 'Mas Amedda',
#   'height': '196',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'blue',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/50/',
#   'films': ['http://swapi.dev/api/films/4/', 'http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/27/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:53:26.457000Z',
#   'edited': '2014-12-20T21:17:50.442000Z',
#   'url': 'http://swapi.dev/api/people/59/'},
#  {'name': 'Gregar Typho',
#   'height': '185',
#   'mass': '85',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/39/'],
#   'created': '2014-12-20T11:10:10.381000Z',
#   'edited': '2014-12-20T21:17:50.445000Z',
#   'url': 'http://swapi.dev/api/people/60/'},
#  {'name': 'Cordé',
#   'height': '157',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T11:11:39.630000Z',
#   'edited': '2014-12-20T21:17:50.449000Z',
#   'url': 'http://swapi.dev/api/people/61/'},
#  {'name': 'Cliegg Lars',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '82BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T15:59:03.958000Z',
#   'edited': '2014-12-20T21:17:50.451000Z',
#   'url': 'http://swapi.dev/api/people/62/'},
#  {'name': 'Poggle the Lesser',
#   'height': '183',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/11/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/28/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:40:43.977000Z',
#   'edited': '2014-12-20T21:17:50.453000Z',
#   'url': 'http://swapi.dev/api/people/63/'},
#  {'name': 'Luminara Unduli',
#   'height': '170',
#   'mass': '56.2',
#   'hair_color': 'black',
#   'skin_color': 'yellow',
#   'eye_color': 'blue',
#   'birth_year': '58BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/51/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/29/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:45:53.668000Z',
#   'edited': '2014-12-20T21:17:50.455000Z',
#   'url': 'http://swapi.dev/api/people/64/'},
#  {'name': 'Barriss Offee',
#   'height': '166',
#   'mass': '50',
#   'hair_color': 'black',
#   'skin_color': 'yellow',
#   'eye_color': 'blue',
#   'birth_year': '40BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/51/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/29/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:46:40.440000Z',
#   'edited': '2014-12-20T21:17:50.457000Z',
#   'url': 'http://swapi.dev/api/people/65/'},
#  {'name': 'Dormé',
#   'height': '165',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:49:14.640000Z',
#   'edited': '2014-12-20T21:17:50.460000Z',
#   'url': 'http://swapi.dev/api/people/66/'},
#  {'name': 'Dooku',
#   'height': '193',
#   'mass': '80',
#   'hair_color': 'white',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '102BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/52/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/55/'],
#   'starships': [],
#   'created': '2014-12-20T16:52:14.726000Z',
#   'edited': '2014-12-20T21:17:50.462000Z',
#   'url': 'http://swapi.dev/api/people/67/'},
#  {'name': 'Bail Prestor Organa',
#   'height': '191',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'tan',
#   'eye_color': 'brown',
#   'birth_year': '67BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:53:08.575000Z',
#   'edited': '2014-12-20T21:17:50.463000Z',
#   'url': 'http://swapi.dev/api/people/68/'},
#  {'name': 'Jango Fett',
#   'height': '183',
#   'mass': '79',
#   'hair_color': 'black',
#   'skin_color': 'tan',
#   'eye_color': 'brown',
#   'birth_year': '66BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/53/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:54:41.620000Z',
#   'edited': '2014-12-20T21:17:50.465000Z',
#   'url': 'http://swapi.dev/api/people/69/'},
#  {'name': 'Zam Wesell',
#   'height': '168',
#   'mass': '55',
#   'hair_color': 'blonde',
#   'skin_color': 'fair, green, yellow',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/54/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/30/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/45/'],
#   'starships': [],
#   'created': '2014-12-20T16:57:44.471000Z',
#   'edited': '2014-12-20T21:17:50.468000Z',
#   'url': 'http://swapi.dev/api/people/70/'},
#  {'name': 'Dexter Jettster',
#   'height': '198',
#   'mass': '102',
#   'hair_color': 'none',
#   'skin_color': 'brown',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/55/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/31/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:28:27.248000Z',
#   'edited': '2014-12-20T21:17:50.470000Z',
#   'url': 'http://swapi.dev/api/people/71/'},
#  {'name': 'Lama Su',
#   'height': '229',
#   'mass': '88',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/32/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:30:50.416000Z',
#   'edited': '2014-12-20T21:17:50.473000Z',
#   'url': 'http://swapi.dev/api/people/72/'},
#  {'name': 'Taun We',
#   'height': '213',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/32/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:31:21.195000Z',
#   'edited': '2014-12-20T21:17:50.474000Z',
#   'url': 'http://swapi.dev/api/people/73/'},
#  {'name': 'Jocasta Nu',
#   'height': '167',
#   'mass': 'unknown',
#   'hair_color': 'white',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:32:51.996000Z',
#   'edited': '2014-12-20T21:17:50.476000Z',
#   'url': 'http://swapi.dev/api/people/74/'},
#  {'name': 'R4-P17',
#   'height': '96',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'silver, red',
#   'eye_color': 'red, blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:43:36.409000Z',
#   'edited': '2014-12-20T21:17:50.478000Z',
#   'url': 'http://swapi.dev/api/people/75/'},
#  {'name': 'Wat Tambor',
#   'height': '193',
#   'mass': '48',
#   'hair_color': 'none',
#   'skin_color': 'green, grey',
#   'eye_color': 'unknown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/56/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/33/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:53:52.607000Z',
#   'edited': '2014-12-20T21:17:50.481000Z',
#   'url': 'http://swapi.dev/api/people/76/'},
#  {'name': 'San Hill',
#   'height': '191',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'gold',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/57/',
#   'films': ['http://swapi.dev/api/films/5/'],
#   'species': ['http://swapi.dev/api/species/34/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:58:17.049000Z',
#   'edited': '2014-12-20T21:17:50.484000Z',
#   'url': 'http://swapi.dev/api/people/77/'},
#  {'name': 'Shaak Ti',
#   'height': '178',
#   'mass': '57',
#   'hair_color': 'none',
#   'skin_color': 'red, blue, white',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/58/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/35/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T18:44:01.103000Z',
#   'edited': '2014-12-20T21:17:50.486000Z',
#   'url': 'http://swapi.dev/api/people/78/'},
#  {'name': 'Grievous',
#   'height': '216',
#   'mass': '159',
#   'hair_color': 'none',
#   'skin_color': 'brown, white',
#   'eye_color': 'green, yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/59/',
#   'films': ['http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/36/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/60/'],
#   'starships': ['http://swapi.dev/api/starships/74/'],
#   'created': '2014-12-20T19:43:53.348000Z',
#   'edited': '2014-12-20T21:17:50.488000Z',
#   'url': 'http://swapi.dev/api/people/79/'},
#  {'name': 'Tarfful',
#   'height': '234',
#   'mass': '136',
#   'hair_color': 'brown',
#   'skin_color': 'brown',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/14/',
#   'films': ['http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/3/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T19:46:34.209000Z',
#   'edited': '2014-12-20T21:17:50.491000Z',
#   'url': 'http://swapi.dev/api/people/80/'},
#  {'name': 'Raymus Antilles',
#   'height': '188',
#   'mass': '79',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': ['http://swapi.dev/api/films/1/', 'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T19:49:35.583000Z',
#   'edited': '2014-12-20T21:17:50.493000Z',
#   'url': 'http://swapi.dev/api/people/81/'},
#  {'name': 'Sly Moore',
#   'height': '178',
#   'mass': '48',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'white',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/60/',
#   'films': ['http://swapi.dev/api/films/5/', 'http://swapi.dev/api/films/6/'],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T20:18:37.619000Z',
#   'edited': '2014-12-20T21:17:50.496000Z',
#   'url': 'http://swapi.dev/api/people/82/'},
#  {'name': 'Tion Medon',
#   'height': '206',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/12/',
#   'films': ['http://swapi.dev/api/films/6/'],
#   'species': ['http://swapi.dev/api/species/37/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T20:35:04.260000Z',
#   'edited': '2014-12-20T21:17:50.498000Z',
#   'url': 'http://swapi.dev/api/people/83/'}]

# %%
len(people)
# Out:
# 82

# %% [markdown]
# Then, I wrote a function to get nested film information.

# %%
def get_nested(d):
    """
    This function is to download nested film information in the api.
    
    Parameters
    ----------
    d: dict
    the json dict you downloaded
       
    Returns
    ----------
    d: dict  
    the nested json dict with additional film information
    
    """
    films_title=[]
    urls = d['films']
    films = [requests.get(url).json() for url in urls]
    
    for x in films:
        films_title.append( {'title' : x['title']} ) 
   
    d['films']  = films_title
    
    return d

# %%
for x in people:
    get_nested(x)

# %%
people
# Out:
# [{'name': 'Luke Skywalker',
#   'height': '172',
#   'mass': '77',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '19BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/14/',
#    'http://swapi.dev/api/vehicles/30/'],
#   'starships': ['http://swapi.dev/api/starships/12/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-09T13:50:51.644000Z',
#   'edited': '2014-12-20T21:17:56.891000Z',
#   'url': 'http://swapi.dev/api/people/1/'},
#  {'name': 'C-3PO',
#   'height': '167',
#   'mass': '75',
#   'hair_color': 'n/a',
#   'skin_color': 'gold',
#   'eye_color': 'yellow',
#   'birth_year': '112BBY',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:10:51.357000Z',
#   'edited': '2014-12-20T21:17:50.309000Z',
#   'url': 'http://swapi.dev/api/people/2/'},
#  {'name': 'R2-D2',
#   'height': '96',
#   'mass': '32',
#   'hair_color': 'n/a',
#   'skin_color': 'white, blue',
#   'eye_color': 'red',
#   'birth_year': '33BBY',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:11:50.376000Z',
#   'edited': '2014-12-20T21:17:50.311000Z',
#   'url': 'http://swapi.dev/api/people/3/'},
#  {'name': 'Darth Vader',
#   'height': '202',
#   'mass': '136',
#   'hair_color': 'none',
#   'skin_color': 'white',
#   'eye_color': 'yellow',
#   'birth_year': '41.9BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/13/'],
#   'created': '2014-12-10T15:18:20.704000Z',
#   'edited': '2014-12-20T21:17:50.313000Z',
#   'url': 'http://swapi.dev/api/people/4/'},
#  {'name': 'Leia Organa',
#   'height': '150',
#   'mass': '49',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '19BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/30/'],
#   'starships': [],
#   'created': '2014-12-10T15:20:09.791000Z',
#   'edited': '2014-12-20T21:17:50.315000Z',
#   'url': 'http://swapi.dev/api/people/5/'},
#  {'name': 'Owen Lars',
#   'height': '178',
#   'mass': '120',
#   'hair_color': 'brown, grey',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '52BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:52:14.024000Z',
#   'edited': '2014-12-20T21:17:50.317000Z',
#   'url': 'http://swapi.dev/api/people/6/'},
#  {'name': 'Beru Whitesun lars',
#   'height': '165',
#   'mass': '75',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '47BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:53:41.121000Z',
#   'edited': '2014-12-20T21:17:50.319000Z',
#   'url': 'http://swapi.dev/api/people/7/'},
#  {'name': 'R5-D4',
#   'height': '97',
#   'mass': '32',
#   'hair_color': 'n/a',
#   'skin_color': 'white, red',
#   'eye_color': 'red',
#   'birth_year': 'unknown',
#   'gender': 'n/a',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'}],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T15:57:50.959000Z',
#   'edited': '2014-12-20T21:17:50.321000Z',
#   'url': 'http://swapi.dev/api/people/8/'},
#  {'name': 'Biggs Darklighter',
#   'height': '183',
#   'mass': '84',
#   'hair_color': 'black',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '24BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'A New Hope'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-10T15:59:50.509000Z',
#   'edited': '2014-12-20T21:17:50.323000Z',
#   'url': 'http://swapi.dev/api/people/9/'},
#  {'name': 'Obi-Wan Kenobi',
#   'height': '182',
#   'mass': '77',
#   'hair_color': 'auburn, white',
#   'skin_color': 'fair',
#   'eye_color': 'blue-gray',
#   'birth_year': '57BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/20/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/38/'],
#   'starships': ['http://swapi.dev/api/starships/48/',
#    'http://swapi.dev/api/starships/59/',
#    'http://swapi.dev/api/starships/64/',
#    'http://swapi.dev/api/starships/65/',
#    'http://swapi.dev/api/starships/74/'],
#   'created': '2014-12-10T16:16:29.192000Z',
#   'edited': '2014-12-20T21:17:50.325000Z',
#   'url': 'http://swapi.dev/api/people/10/'},
#  {'name': 'Anakin Skywalker',
#   'height': '188',
#   'mass': '84',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '41.9BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/44/',
#    'http://swapi.dev/api/vehicles/46/'],
#   'starships': ['http://swapi.dev/api/starships/39/',
#    'http://swapi.dev/api/starships/59/',
#    'http://swapi.dev/api/starships/65/'],
#   'created': '2014-12-10T16:20:44.310000Z',
#   'edited': '2014-12-20T21:17:50.327000Z',
#   'url': 'http://swapi.dev/api/people/11/'},
#  {'name': 'Wilhuff Tarkin',
#   'height': '180',
#   'mass': 'unknown',
#   'hair_color': 'auburn, grey',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '64BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/21/',
#   'films': [{'title': 'A New Hope'}, {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T16:26:56.138000Z',
#   'edited': '2014-12-20T21:17:50.330000Z',
#   'url': 'http://swapi.dev/api/people/12/'},
#  {'name': 'Chewbacca',
#   'height': '228',
#   'mass': '112',
#   'hair_color': 'brown',
#   'skin_color': 'unknown',
#   'eye_color': 'blue',
#   'birth_year': '200BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/14/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/3/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/19/'],
#   'starships': ['http://swapi.dev/api/starships/10/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-10T16:42:45.066000Z',
#   'edited': '2014-12-20T21:17:50.332000Z',
#   'url': 'http://swapi.dev/api/people/13/'},
#  {'name': 'Han Solo',
#   'height': '180',
#   'mass': '80',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '29BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/22/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/',
#    'http://swapi.dev/api/starships/22/'],
#   'created': '2014-12-10T16:49:14.582000Z',
#   'edited': '2014-12-20T21:17:50.334000Z',
#   'url': 'http://swapi.dev/api/people/14/'},
#  {'name': 'Greedo',
#   'height': '173',
#   'mass': '74',
#   'hair_color': 'n/a',
#   'skin_color': 'green',
#   'eye_color': 'black',
#   'birth_year': '44BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/23/',
#   'films': [{'title': 'A New Hope'}],
#   'species': ['http://swapi.dev/api/species/4/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T17:03:30.334000Z',
#   'edited': '2014-12-20T21:17:50.336000Z',
#   'url': 'http://swapi.dev/api/people/15/'},
#  {'name': 'Jabba Desilijic Tiure',
#   'height': '175',
#   'mass': '1,358',
#   'hair_color': 'n/a',
#   'skin_color': 'green-tan, brown',
#   'eye_color': 'orange',
#   'birth_year': '600BBY',
#   'gender': 'hermaphrodite',
#   'homeworld': 'http://swapi.dev/api/planets/24/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/5/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-10T17:11:31.638000Z',
#   'edited': '2014-12-20T21:17:50.338000Z',
#   'url': 'http://swapi.dev/api/people/16/'},
#  {'name': 'Wedge Antilles',
#   'height': '170',
#   'mass': '77',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'hazel',
#   'birth_year': '21BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/22/',
#   'films': [{'title': 'A New Hope'},
#    {'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/14/'],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-12T11:08:06.469000Z',
#   'edited': '2014-12-20T21:17:50.341000Z',
#   'url': 'http://swapi.dev/api/people/18/'},
#  {'name': 'Jek Tono Porkins',
#   'height': '180',
#   'mass': '110',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/26/',
#   'films': [{'title': 'A New Hope'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/12/'],
#   'created': '2014-12-12T11:16:56.569000Z',
#   'edited': '2014-12-20T21:17:50.343000Z',
#   'url': 'http://swapi.dev/api/people/19/'},
#  {'name': 'Yoda',
#   'height': '66',
#   'mass': '17',
#   'hair_color': 'white',
#   'skin_color': 'green',
#   'eye_color': 'brown',
#   'birth_year': '896BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': [{'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/6/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:26:01.042000Z',
#   'edited': '2014-12-20T21:17:50.345000Z',
#   'url': 'http://swapi.dev/api/people/20/'},
#  {'name': 'Palpatine',
#   'height': '170',
#   'mass': '75',
#   'hair_color': 'grey',
#   'skin_color': 'pale',
#   'eye_color': 'yellow',
#   'birth_year': '82BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:48:05.971000Z',
#   'edited': '2014-12-20T21:17:50.347000Z',
#   'url': 'http://swapi.dev/api/people/21/'},
#  {'name': 'Boba Fett',
#   'height': '183',
#   'mass': '78.2',
#   'hair_color': 'black',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '31.5BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': [{'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'},
#    {'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/21/'],
#   'created': '2014-12-15T12:49:32.457000Z',
#   'edited': '2014-12-20T21:17:50.349000Z',
#   'url': 'http://swapi.dev/api/people/22/'},
#  {'name': 'IG-88',
#   'height': '200',
#   'mass': '140',
#   'hair_color': 'none',
#   'skin_color': 'metal',
#   'eye_color': 'red',
#   'birth_year': '15BBY',
#   'gender': 'none',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': [{'title': 'The Empire Strikes Back'}],
#   'species': ['http://swapi.dev/api/species/2/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:51:10.076000Z',
#   'edited': '2014-12-20T21:17:50.351000Z',
#   'url': 'http://swapi.dev/api/people/23/'},
#  {'name': 'Bossk',
#   'height': '190',
#   'mass': '113',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'red',
#   'birth_year': '53BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/29/',
#   'films': [{'title': 'The Empire Strikes Back'}],
#   'species': ['http://swapi.dev/api/species/7/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T12:53:49.297000Z',
#   'edited': '2014-12-20T21:17:50.355000Z',
#   'url': 'http://swapi.dev/api/people/24/'},
#  {'name': 'Lando Calrissian',
#   'height': '177',
#   'mass': '79',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '31BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/30/',
#   'films': [{'title': 'The Empire Strikes Back'},
#    {'title': 'Return of the Jedi'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/'],
#   'created': '2014-12-15T12:56:32.683000Z',
#   'edited': '2014-12-20T21:17:50.357000Z',
#   'url': 'http://swapi.dev/api/people/25/'},
#  {'name': 'Lobot',
#   'height': '175',
#   'mass': '79',
#   'hair_color': 'none',
#   'skin_color': 'light',
#   'eye_color': 'blue',
#   'birth_year': '37BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/6/',
#   'films': [{'title': 'The Empire Strikes Back'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-15T13:01:57.178000Z',
#   'edited': '2014-12-20T21:17:50.359000Z',
#   'url': 'http://swapi.dev/api/people/26/'},
#  {'name': 'Ackbar',
#   'height': '180',
#   'mass': '83',
#   'hair_color': 'none',
#   'skin_color': 'brown mottle',
#   'eye_color': 'orange',
#   'birth_year': '41BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/31/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': ['http://swapi.dev/api/species/8/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:07:50.584000Z',
#   'edited': '2014-12-20T21:17:50.362000Z',
#   'url': 'http://swapi.dev/api/people/27/'},
#  {'name': 'Mon Mothma',
#   'height': '150',
#   'mass': 'unknown',
#   'hair_color': 'auburn',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '48BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/32/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:12:38.895000Z',
#   'edited': '2014-12-20T21:17:50.364000Z',
#   'url': 'http://swapi.dev/api/people/28/'},
#  {'name': 'Arvel Crynyd',
#   'height': 'unknown',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/28/'],
#   'created': '2014-12-18T11:16:33.020000Z',
#   'edited': '2014-12-20T21:17:50.367000Z',
#   'url': 'http://swapi.dev/api/people/29/'},
#  {'name': 'Wicket Systri Warrick',
#   'height': '88',
#   'mass': '20',
#   'hair_color': 'brown',
#   'skin_color': 'brown',
#   'eye_color': 'brown',
#   'birth_year': '8BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/7/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': ['http://swapi.dev/api/species/9/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-18T11:21:58.954000Z',
#   'edited': '2014-12-20T21:17:50.369000Z',
#   'url': 'http://swapi.dev/api/people/30/'},
#  {'name': 'Nien Nunb',
#   'height': '160',
#   'mass': '68',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/33/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': ['http://swapi.dev/api/species/10/'],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/10/'],
#   'created': '2014-12-18T11:26:18.541000Z',
#   'edited': '2014-12-20T21:17:50.371000Z',
#   'url': 'http://swapi.dev/api/people/31/'},
#  {'name': 'Qui-Gon Jinn',
#   'height': '193',
#   'mass': '89',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '92BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': [],
#   'vehicles': ['http://swapi.dev/api/vehicles/38/'],
#   'starships': [],
#   'created': '2014-12-19T16:54:53.618000Z',
#   'edited': '2014-12-20T21:17:50.375000Z',
#   'url': 'http://swapi.dev/api/people/32/'},
#  {'name': 'Nute Gunray',
#   'height': '191',
#   'mass': '90',
#   'hair_color': 'none',
#   'skin_color': 'mottled green',
#   'eye_color': 'red',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/18/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/11/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:05:57.357000Z',
#   'edited': '2014-12-20T21:17:50.377000Z',
#   'url': 'http://swapi.dev/api/people/33/'},
#  {'name': 'Finis Valorum',
#   'height': '170',
#   'mass': 'unknown',
#   'hair_color': 'blond',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '91BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:21:45.915000Z',
#   'edited': '2014-12-20T21:17:50.379000Z',
#   'url': 'http://swapi.dev/api/people/34/'},
#  {'name': 'Padmé Amidala',
#   'height': '185',
#   'mass': '45',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': '46BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/39/',
#    'http://swapi.dev/api/starships/49/',
#    'http://swapi.dev/api/starships/64/'],
#   'created': '2014-12-19T17:28:26.926000Z',
#   'edited': '2014-12-20T21:17:50.381000Z',
#   'url': 'http://swapi.dev/api/people/35/'},
#  {'name': 'Jar Jar Binks',
#   'height': '196',
#   'mass': '66',
#   'hair_color': 'none',
#   'skin_color': 'orange',
#   'eye_color': 'orange',
#   'birth_year': '52BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:29:32.489000Z',
#   'edited': '2014-12-20T21:17:50.383000Z',
#   'url': 'http://swapi.dev/api/people/36/'},
#  {'name': 'Roos Tarpals',
#   'height': '224',
#   'mass': '82',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:32:56.741000Z',
#   'edited': '2014-12-20T21:17:50.385000Z',
#   'url': 'http://swapi.dev/api/people/37/'},
#  {'name': 'Rugor Nass',
#   'height': '206',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/12/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:33:38.909000Z',
#   'edited': '2014-12-20T21:17:50.388000Z',
#   'url': 'http://swapi.dev/api/people/38/'},
#  {'name': 'Ric Olié',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/40/'],
#   'created': '2014-12-19T17:45:01.522000Z',
#   'edited': '2014-12-20T21:17:50.392000Z',
#   'url': 'http://swapi.dev/api/people/39/'},
#  {'name': 'Watto',
#   'height': '137',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'blue, grey',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/34/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/13/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:48:54.647000Z',
#   'edited': '2014-12-20T21:17:50.395000Z',
#   'url': 'http://swapi.dev/api/people/40/'},
#  {'name': 'Sebulba',
#   'height': '112',
#   'mass': '40',
#   'hair_color': 'none',
#   'skin_color': 'grey, red',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/35/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/14/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:53:02.586000Z',
#   'edited': '2014-12-20T21:17:50.397000Z',
#   'url': 'http://swapi.dev/api/people/41/'},
#  {'name': 'Quarsh Panaka',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '62BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:55:43.348000Z',
#   'edited': '2014-12-20T21:17:50.399000Z',
#   'url': 'http://swapi.dev/api/people/42/'},
#  {'name': 'Shmi Skywalker',
#   'height': '163',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '72BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-19T17:57:41.191000Z',
#   'edited': '2014-12-20T21:17:50.401000Z',
#   'url': 'http://swapi.dev/api/people/43/'},
#  {'name': 'Darth Maul',
#   'height': '175',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'red',
#   'eye_color': 'yellow',
#   'birth_year': '54BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/36/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/22/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/42/'],
#   'starships': ['http://swapi.dev/api/starships/41/'],
#   'created': '2014-12-19T18:00:41.929000Z',
#   'edited': '2014-12-20T21:17:50.403000Z',
#   'url': 'http://swapi.dev/api/people/44/'},
#  {'name': 'Bib Fortuna',
#   'height': '180',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'pink',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/37/',
#   'films': [{'title': 'Return of the Jedi'}],
#   'species': ['http://swapi.dev/api/species/15/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:47:02.512000Z',
#   'edited': '2014-12-20T21:17:50.407000Z',
#   'url': 'http://swapi.dev/api/people/45/'},
#  {'name': 'Ayla Secura',
#   'height': '178',
#   'mass': '55',
#   'hair_color': 'none',
#   'skin_color': 'blue',
#   'eye_color': 'hazel',
#   'birth_year': '48BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/37/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/15/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:48:01.172000Z',
#   'edited': '2014-12-20T21:17:50.409000Z',
#   'url': 'http://swapi.dev/api/people/46/'},
#  {'name': 'Ratts Tyerel',
#   'height': '79',
#   'mass': '15',
#   'hair_color': 'none',
#   'skin_color': 'grey, blue',
#   'eye_color': 'unknown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/38/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/16/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:53:15.086000Z',
#   'edited': '2014-12-20T21:17:50.410000Z',
#   'url': 'http://swapi.dev/api/people/47/'},
#  {'name': 'Dud Bolt',
#   'height': '94',
#   'mass': '45',
#   'hair_color': 'none',
#   'skin_color': 'blue, grey',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/39/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/17/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T09:57:31.858000Z',
#   'edited': '2014-12-20T21:17:50.414000Z',
#   'url': 'http://swapi.dev/api/people/48/'},
#  {'name': 'Gasgano',
#   'height': '122',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'white, blue',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/40/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/18/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:02:12.223000Z',
#   'edited': '2014-12-20T21:17:50.416000Z',
#   'url': 'http://swapi.dev/api/people/49/'},
#  {'name': 'Ben Quadinaros',
#   'height': '163',
#   'mass': '65',
#   'hair_color': 'none',
#   'skin_color': 'grey, green, yellow',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/41/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/19/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:08:33.777000Z',
#   'edited': '2014-12-20T21:17:50.417000Z',
#   'url': 'http://swapi.dev/api/people/50/'},
#  {'name': 'Mace Windu',
#   'height': '188',
#   'mass': '84',
#   'hair_color': 'none',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': '72BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/42/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:12:30.846000Z',
#   'edited': '2014-12-20T21:17:50.420000Z',
#   'url': 'http://swapi.dev/api/people/51/'},
#  {'name': 'Ki-Adi-Mundi',
#   'height': '198',
#   'mass': '82',
#   'hair_color': 'white',
#   'skin_color': 'pale',
#   'eye_color': 'yellow',
#   'birth_year': '92BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/43/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/20/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:15:32.293000Z',
#   'edited': '2014-12-20T21:17:50.422000Z',
#   'url': 'http://swapi.dev/api/people/52/'},
#  {'name': 'Kit Fisto',
#   'height': '196',
#   'mass': '87',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/44/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/21/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:18:57.202000Z',
#   'edited': '2014-12-20T21:17:50.424000Z',
#   'url': 'http://swapi.dev/api/people/53/'},
#  {'name': 'Eeth Koth',
#   'height': '171',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'brown',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/45/',
#   'films': [{'title': 'The Phantom Menace'}, {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/22/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:26:47.902000Z',
#   'edited': '2014-12-20T21:17:50.427000Z',
#   'url': 'http://swapi.dev/api/people/54/'},
#  {'name': 'Adi Gallia',
#   'height': '184',
#   'mass': '50',
#   'hair_color': 'none',
#   'skin_color': 'dark',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': [{'title': 'The Phantom Menace'}, {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/23/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:29:11.661000Z',
#   'edited': '2014-12-20T21:17:50.432000Z',
#   'url': 'http://swapi.dev/api/people/55/'},
#  {'name': 'Saesee Tiin',
#   'height': '188',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'orange',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/47/',
#   'films': [{'title': 'The Phantom Menace'}, {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/24/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:32:11.669000Z',
#   'edited': '2014-12-20T21:17:50.434000Z',
#   'url': 'http://swapi.dev/api/people/56/'},
#  {'name': 'Yarael Poof',
#   'height': '264',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'white',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/48/',
#   'films': [{'title': 'The Phantom Menace'}],
#   'species': ['http://swapi.dev/api/species/25/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:34:48.725000Z',
#   'edited': '2014-12-20T21:17:50.437000Z',
#   'url': 'http://swapi.dev/api/people/57/'},
#  {'name': 'Plo Koon',
#   'height': '188',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'orange',
#   'eye_color': 'black',
#   'birth_year': '22BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/49/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/26/'],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/48/'],
#   'created': '2014-12-20T10:49:19.859000Z',
#   'edited': '2014-12-20T21:17:50.439000Z',
#   'url': 'http://swapi.dev/api/people/58/'},
#  {'name': 'Mas Amedda',
#   'height': '196',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'blue',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/50/',
#   'films': [{'title': 'The Phantom Menace'},
#    {'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/27/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T10:53:26.457000Z',
#   'edited': '2014-12-20T21:17:50.442000Z',
#   'url': 'http://swapi.dev/api/people/59/'},
#  {'name': 'Gregar Typho',
#   'height': '185',
#   'mass': '85',
#   'hair_color': 'black',
#   'skin_color': 'dark',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': ['http://swapi.dev/api/starships/39/'],
#   'created': '2014-12-20T11:10:10.381000Z',
#   'edited': '2014-12-20T21:17:50.445000Z',
#   'url': 'http://swapi.dev/api/people/60/'},
#  {'name': 'Cordé',
#   'height': '157',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T11:11:39.630000Z',
#   'edited': '2014-12-20T21:17:50.449000Z',
#   'url': 'http://swapi.dev/api/people/61/'},
#  {'name': 'Cliegg Lars',
#   'height': '183',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': '82BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/1/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T15:59:03.958000Z',
#   'edited': '2014-12-20T21:17:50.451000Z',
#   'url': 'http://swapi.dev/api/people/62/'},
#  {'name': 'Poggle the Lesser',
#   'height': '183',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'green',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/11/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/28/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:40:43.977000Z',
#   'edited': '2014-12-20T21:17:50.453000Z',
#   'url': 'http://swapi.dev/api/people/63/'},
#  {'name': 'Luminara Unduli',
#   'height': '170',
#   'mass': '56.2',
#   'hair_color': 'black',
#   'skin_color': 'yellow',
#   'eye_color': 'blue',
#   'birth_year': '58BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/51/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/29/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:45:53.668000Z',
#   'edited': '2014-12-20T21:17:50.455000Z',
#   'url': 'http://swapi.dev/api/people/64/'},
#  {'name': 'Barriss Offee',
#   'height': '166',
#   'mass': '50',
#   'hair_color': 'black',
#   'skin_color': 'yellow',
#   'eye_color': 'blue',
#   'birth_year': '40BBY',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/51/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/29/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:46:40.440000Z',
#   'edited': '2014-12-20T21:17:50.457000Z',
#   'url': 'http://swapi.dev/api/people/65/'},
#  {'name': 'Dormé',
#   'height': '165',
#   'mass': 'unknown',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/8/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:49:14.640000Z',
#   'edited': '2014-12-20T21:17:50.460000Z',
#   'url': 'http://swapi.dev/api/people/66/'},
#  {'name': 'Dooku',
#   'height': '193',
#   'mass': '80',
#   'hair_color': 'white',
#   'skin_color': 'fair',
#   'eye_color': 'brown',
#   'birth_year': '102BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/52/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/55/'],
#   'starships': [],
#   'created': '2014-12-20T16:52:14.726000Z',
#   'edited': '2014-12-20T21:17:50.462000Z',
#   'url': 'http://swapi.dev/api/people/67/'},
#  {'name': 'Bail Prestor Organa',
#   'height': '191',
#   'mass': 'unknown',
#   'hair_color': 'black',
#   'skin_color': 'tan',
#   'eye_color': 'brown',
#   'birth_year': '67BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:53:08.575000Z',
#   'edited': '2014-12-20T21:17:50.463000Z',
#   'url': 'http://swapi.dev/api/people/68/'},
#  {'name': 'Jango Fett',
#   'height': '183',
#   'mass': '79',
#   'hair_color': 'black',
#   'skin_color': 'tan',
#   'eye_color': 'brown',
#   'birth_year': '66BBY',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/53/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T16:54:41.620000Z',
#   'edited': '2014-12-20T21:17:50.465000Z',
#   'url': 'http://swapi.dev/api/people/69/'},
#  {'name': 'Zam Wesell',
#   'height': '168',
#   'mass': '55',
#   'hair_color': 'blonde',
#   'skin_color': 'fair, green, yellow',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/54/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/30/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/45/'],
#   'starships': [],
#   'created': '2014-12-20T16:57:44.471000Z',
#   'edited': '2014-12-20T21:17:50.468000Z',
#   'url': 'http://swapi.dev/api/people/70/'},
#  {'name': 'Dexter Jettster',
#   'height': '198',
#   'mass': '102',
#   'hair_color': 'none',
#   'skin_color': 'brown',
#   'eye_color': 'yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/55/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/31/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:28:27.248000Z',
#   'edited': '2014-12-20T21:17:50.470000Z',
#   'url': 'http://swapi.dev/api/people/71/'},
#  {'name': 'Lama Su',
#   'height': '229',
#   'mass': '88',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/32/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:30:50.416000Z',
#   'edited': '2014-12-20T21:17:50.473000Z',
#   'url': 'http://swapi.dev/api/people/72/'},
#  {'name': 'Taun We',
#   'height': '213',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/10/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/32/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:31:21.195000Z',
#   'edited': '2014-12-20T21:17:50.474000Z',
#   'url': 'http://swapi.dev/api/people/73/'},
#  {'name': 'Jocasta Nu',
#   'height': '167',
#   'mass': 'unknown',
#   'hair_color': 'white',
#   'skin_color': 'fair',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/9/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/1/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:32:51.996000Z',
#   'edited': '2014-12-20T21:17:50.476000Z',
#   'url': 'http://swapi.dev/api/people/74/'},
#  {'name': 'R4-P17',
#   'height': '96',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'silver, red',
#   'eye_color': 'red, blue',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/28/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:43:36.409000Z',
#   'edited': '2014-12-20T21:17:50.478000Z',
#   'url': 'http://swapi.dev/api/people/75/'},
#  {'name': 'Wat Tambor',
#   'height': '193',
#   'mass': '48',
#   'hair_color': 'none',
#   'skin_color': 'green, grey',
#   'eye_color': 'unknown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/56/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/33/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:53:52.607000Z',
#   'edited': '2014-12-20T21:17:50.481000Z',
#   'url': 'http://swapi.dev/api/people/76/'},
#  {'name': 'San Hill',
#   'height': '191',
#   'mass': 'unknown',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'gold',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/57/',
#   'films': [{'title': 'Attack of the Clones'}],
#   'species': ['http://swapi.dev/api/species/34/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T17:58:17.049000Z',
#   'edited': '2014-12-20T21:17:50.484000Z',
#   'url': 'http://swapi.dev/api/people/77/'},
#  {'name': 'Shaak Ti',
#   'height': '178',
#   'mass': '57',
#   'hair_color': 'none',
#   'skin_color': 'red, blue, white',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/58/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/35/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T18:44:01.103000Z',
#   'edited': '2014-12-20T21:17:50.486000Z',
#   'url': 'http://swapi.dev/api/people/78/'},
#  {'name': 'Grievous',
#   'height': '216',
#   'mass': '159',
#   'hair_color': 'none',
#   'skin_color': 'brown, white',
#   'eye_color': 'green, yellow',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/59/',
#   'films': [{'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/36/'],
#   'vehicles': ['http://swapi.dev/api/vehicles/60/'],
#   'starships': ['http://swapi.dev/api/starships/74/'],
#   'created': '2014-12-20T19:43:53.348000Z',
#   'edited': '2014-12-20T21:17:50.488000Z',
#   'url': 'http://swapi.dev/api/people/79/'},
#  {'name': 'Tarfful',
#   'height': '234',
#   'mass': '136',
#   'hair_color': 'brown',
#   'skin_color': 'brown',
#   'eye_color': 'blue',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/14/',
#   'films': [{'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/3/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T19:46:34.209000Z',
#   'edited': '2014-12-20T21:17:50.491000Z',
#   'url': 'http://swapi.dev/api/people/80/'},
#  {'name': 'Raymus Antilles',
#   'height': '188',
#   'mass': '79',
#   'hair_color': 'brown',
#   'skin_color': 'light',
#   'eye_color': 'brown',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/2/',
#   'films': [{'title': 'A New Hope'}, {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T19:49:35.583000Z',
#   'edited': '2014-12-20T21:17:50.493000Z',
#   'url': 'http://swapi.dev/api/people/81/'},
#  {'name': 'Sly Moore',
#   'height': '178',
#   'mass': '48',
#   'hair_color': 'none',
#   'skin_color': 'pale',
#   'eye_color': 'white',
#   'birth_year': 'unknown',
#   'gender': 'female',
#   'homeworld': 'http://swapi.dev/api/planets/60/',
#   'films': [{'title': 'Attack of the Clones'},
#    {'title': 'Revenge of the Sith'}],
#   'species': [],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T20:18:37.619000Z',
#   'edited': '2014-12-20T21:17:50.496000Z',
#   'url': 'http://swapi.dev/api/people/82/'},
#  {'name': 'Tion Medon',
#   'height': '206',
#   'mass': '80',
#   'hair_color': 'none',
#   'skin_color': 'grey',
#   'eye_color': 'black',
#   'birth_year': 'unknown',
#   'gender': 'male',
#   'homeworld': 'http://swapi.dev/api/planets/12/',
#   'films': [{'title': 'Revenge of the Sith'}],
#   'species': ['http://swapi.dev/api/species/37/'],
#   'vehicles': [],
#   'starships': [],
#   'created': '2014-12-20T20:35:04.260000Z',
#   'edited': '2014-12-20T21:17:50.498000Z',
#   'url': 'http://swapi.dev/api/people/83/'}]

# %% [markdown]
# ### 2. Data analysis

# %%
df = pd.json_normalize(people)
df
# Out:
#                name height mass hair_color    skin_color      eye_color  \
# 0    Luke Skywalker    172   77      blond          fair           blue
# 1             C-3PO    167   75        n/a          gold         yellow
# 2             R2-D2     96   32        n/a   white, blue            red
# 3       Darth Vader    202  136       none         white         yellow
# 4       Leia Organa    150   49      brown         light          brown
# ..              ...    ...  ...        ...           ...            ...
# 77         Grievous    216  159       none  brown, white  green, yellow
# 78          Tarfful    234  136      brown         brown           blue
# 79  Raymus Antilles    188   79      brown         light          brown
# 80        Sly Moore    178   48       none          pale          white
# 81       Tion Medon    206   80       none          grey          black
#
#    birth_year  gender                         homeworld  \
# 0       19BBY    male   http://swapi.dev/api/planets/1/
# 1      112BBY     n/a   http://swapi.dev/api/planets/1/
# 2       33BBY     n/a   http://swapi.dev/api/planets/8/
# 3     41.9BBY    male   http://swapi.dev/api/planets/1/
# 4       19BBY  female   http://swapi.dev/api/planets/2/
# ..        ...     ...                               ...
# 77    unknown    male  http://swapi.dev/api/planets/59/
# 78    unknown    male  http://swapi.dev/api/planets/14/
# 79    unknown    male   http://swapi.dev/api/planets/2/
# 80    unknown  female  http://swapi.dev/api/planets/60/
# 81    unknown    male  http://swapi.dev/api/planets/12/
#
#                                                 films  \
# 0   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 1   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 2   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 3   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 4   [{'title': 'A New Hope'}, {'title': 'The Empir...
# ..                                                ...
# 77                 [{'title': 'Revenge of the Sith'}]
# 78                 [{'title': 'Revenge of the Sith'}]
# 79  [{'title': 'A New Hope'}, {'title': 'Revenge o...
# 80  [{'title': 'Attack of the Clones'}, {'title': ...
# 81                 [{'title': 'Revenge of the Sith'}]
#
#                                species  \
# 0                                   []
# 1    [http://swapi.dev/api/species/2/]
# 2    [http://swapi.dev/api/species/2/]
# 3                                   []
# 4                                   []
# ..                                 ...
# 77  [http://swapi.dev/api/species/36/]
# 78   [http://swapi.dev/api/species/3/]
# 79                                  []
# 80                                  []
# 81  [http://swapi.dev/api/species/37/]
#
#                                              vehicles  \
# 0   [http://swapi.dev/api/vehicles/14/, http://swa...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                 [http://swapi.dev/api/vehicles/30/]
# ..                                                ...
# 77                [http://swapi.dev/api/vehicles/60/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                                             starships  \
# 0   [http://swapi.dev/api/starships/12/, http://sw...
# 1                                                  []
# 2                                                  []
# 3                [http://swapi.dev/api/starships/13/]
# 4                                                  []
# ..                                                ...
# 77               [http://swapi.dev/api/starships/74/]
# 78                                                 []
# 79                                                 []
# 80                                                 []
# 81                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# ..                          ...                          ...
# 77  2014-12-20T19:43:53.348000Z  2014-12-20T21:17:50.488000Z
# 78  2014-12-20T19:46:34.209000Z  2014-12-20T21:17:50.491000Z
# 79  2014-12-20T19:49:35.583000Z  2014-12-20T21:17:50.493000Z
# 80  2014-12-20T20:18:37.619000Z  2014-12-20T21:17:50.496000Z
# 81  2014-12-20T20:35:04.260000Z  2014-12-20T21:17:50.498000Z
#
#                                 url
# 0    http://swapi.dev/api/people/1/
# 1    http://swapi.dev/api/people/2/
# 2    http://swapi.dev/api/people/3/
# 3    http://swapi.dev/api/people/4/
# 4    http://swapi.dev/api/people/5/
# ..                              ...
# 77  http://swapi.dev/api/people/79/
# 78  http://swapi.dev/api/people/80/
# 79  http://swapi.dev/api/people/81/
# 80  http://swapi.dev/api/people/82/
# 81  http://swapi.dev/api/people/83/
#
# [82 rows x 16 columns]

# %% [markdown]
# For the birth year of the person, using the in-universe standard of BBY or ABY - Before the Battle of Yavin or After the Battle of Yavin. The Battle of Yavin is a battle that occurs at the end of Star Wars episode IV: A New Hope.

# %% [markdown]
# Thus, we should only look at those with BBY.

# %%
df1 = df[df['birth_year'].str.contains("BBY")]
df1
# Out:
#                      name height     mass     hair_color        skin_color  \
# 0          Luke Skywalker    172       77          blond              fair
# 1                   C-3PO    167       75            n/a              gold
# 2                   R2-D2     96       32            n/a       white, blue
# 3             Darth Vader    202      136           none             white
# 4             Leia Organa    150       49          brown             light
# 5               Owen Lars    178      120    brown, grey             light
# 6      Beru Whitesun lars    165       75          brown             light
# 8       Biggs Darklighter    183       84          black             light
# 9          Obi-Wan Kenobi    182       77  auburn, white              fair
# 10       Anakin Skywalker    188       84          blond              fair
# 11         Wilhuff Tarkin    180  unknown   auburn, grey              fair
# 12              Chewbacca    228      112          brown           unknown
# 13               Han Solo    180       80          brown              fair
# 14                 Greedo    173       74            n/a             green
# 15  Jabba Desilijic Tiure    175    1,358            n/a  green-tan, brown
# 16         Wedge Antilles    170       77          brown              fair
# 18                   Yoda     66       17          white             green
# 19              Palpatine    170       75           grey              pale
# 20              Boba Fett    183     78.2          black              fair
# 21                  IG-88    200      140           none             metal
# 22                  Bossk    190      113           none             green
# 23       Lando Calrissian    177       79          black              dark
# 24                  Lobot    175       79           none             light
# 25                 Ackbar    180       83           none      brown mottle
# 26             Mon Mothma    150  unknown         auburn              fair
# 28  Wicket Systri Warrick     88       20          brown             brown
# 30           Qui-Gon Jinn    193       89          brown              fair
# 32          Finis Valorum    170  unknown          blond              fair
# 33          Padmé Amidala    185       45          brown             light
# 34          Jar Jar Binks    196       66           none            orange
# 40          Quarsh Panaka    183  unknown          black              dark
# 41         Shmi Skywalker    163  unknown          black              fair
# 42             Darth Maul    175       80           none               red
# 44            Ayla Secura    178       55           none              blue
# 49             Mace Windu    188       84           none              dark
# 50           Ki-Adi-Mundi    198       82          white              pale
# 56               Plo Koon    188       80           none            orange
# 60            Cliegg Lars    183  unknown          brown              fair
# 62        Luminara Unduli    170     56.2          black            yellow
# 63          Barriss Offee    166       50          black            yellow
# 65                  Dooku    193       80          white              fair
# 66    Bail Prestor Organa    191  unknown          black               tan
# 67             Jango Fett    183       79          black               tan
#
#     eye_color birth_year         gender                         homeworld  \
# 0        blue      19BBY           male   http://swapi.dev/api/planets/1/
# 1      yellow     112BBY            n/a   http://swapi.dev/api/planets/1/
# 2         red      33BBY            n/a   http://swapi.dev/api/planets/8/
# 3      yellow    41.9BBY           male   http://swapi.dev/api/planets/1/
# 4       brown      19BBY         female   http://swapi.dev/api/planets/2/
# 5        blue      52BBY           male   http://swapi.dev/api/planets/1/
# 6        blue      47BBY         female   http://swapi.dev/api/planets/1/
# 8       brown      24BBY           male   http://swapi.dev/api/planets/1/
# 9   blue-gray      57BBY           male  http://swapi.dev/api/planets/20/
# 10       blue    41.9BBY           male   http://swapi.dev/api/planets/1/
# 11       blue      64BBY           male  http://swapi.dev/api/planets/21/
# 12       blue     200BBY           male  http://swapi.dev/api/planets/14/
# 13      brown      29BBY           male  http://swapi.dev/api/planets/22/
# 14      black      44BBY           male  http://swapi.dev/api/planets/23/
# 15     orange     600BBY  hermaphrodite  http://swapi.dev/api/planets/24/
# 16      hazel      21BBY           male  http://swapi.dev/api/planets/22/
# 18      brown     896BBY           male  http://swapi.dev/api/planets/28/
# 19     yellow      82BBY           male   http://swapi.dev/api/planets/8/
# 20      brown    31.5BBY           male  http://swapi.dev/api/planets/10/
# 21        red      15BBY           none  http://swapi.dev/api/planets/28/
# 22        red      53BBY           male  http://swapi.dev/api/planets/29/
# 23      brown      31BBY           male  http://swapi.dev/api/planets/30/
# 24       blue      37BBY           male   http://swapi.dev/api/planets/6/
# 25     orange      41BBY           male  http://swapi.dev/api/planets/31/
# 26       blue      48BBY         female  http://swapi.dev/api/planets/32/
# 28      brown       8BBY           male   http://swapi.dev/api/planets/7/
# 30       blue      92BBY           male  http://swapi.dev/api/planets/28/
# 32       blue      91BBY           male   http://swapi.dev/api/planets/9/
# 33      brown      46BBY         female   http://swapi.dev/api/planets/8/
# 34     orange      52BBY           male   http://swapi.dev/api/planets/8/
# 40      brown      62BBY           male   http://swapi.dev/api/planets/8/
# 41      brown      72BBY         female   http://swapi.dev/api/planets/1/
# 42     yellow      54BBY           male  http://swapi.dev/api/planets/36/
# 44      hazel      48BBY         female  http://swapi.dev/api/planets/37/
# 49      brown      72BBY           male  http://swapi.dev/api/planets/42/
# 50     yellow      92BBY           male  http://swapi.dev/api/planets/43/
# 56      black      22BBY           male  http://swapi.dev/api/planets/49/
# 60       blue      82BBY           male   http://swapi.dev/api/planets/1/
# 62       blue      58BBY         female  http://swapi.dev/api/planets/51/
# 63       blue      40BBY         female  http://swapi.dev/api/planets/51/
# 65      brown     102BBY           male  http://swapi.dev/api/planets/52/
# 66      brown      67BBY           male   http://swapi.dev/api/planets/2/
# 67      brown      66BBY           male  http://swapi.dev/api/planets/53/
#
#                                                 films  \
# 0   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 1   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 2   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 3   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 4   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 5   [{'title': 'A New Hope'}, {'title': 'Attack of...
# 6   [{'title': 'A New Hope'}, {'title': 'Attack of...
# 8                           [{'title': 'A New Hope'}]
# 9   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 10  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 11  [{'title': 'A New Hope'}, {'title': 'Revenge o...
# 12  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 13  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 14                          [{'title': 'A New Hope'}]
# 15  [{'title': 'A New Hope'}, {'title': 'Return of...
# 16  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 18  [{'title': 'The Empire Strikes Back'}, {'title...
# 19  [{'title': 'The Empire Strikes Back'}, {'title...
# 20  [{'title': 'The Empire Strikes Back'}, {'title...
# 21             [{'title': 'The Empire Strikes Back'}]
# 22             [{'title': 'The Empire Strikes Back'}]
# 23  [{'title': 'The Empire Strikes Back'}, {'title...
# 24             [{'title': 'The Empire Strikes Back'}]
# 25                  [{'title': 'Return of the Jedi'}]
# 26                  [{'title': 'Return of the Jedi'}]
# 28                  [{'title': 'Return of the Jedi'}]
# 30                  [{'title': 'The Phantom Menace'}]
# 32                  [{'title': 'The Phantom Menace'}]
# 33  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 34  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 40                  [{'title': 'The Phantom Menace'}]
# 41  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 42                  [{'title': 'The Phantom Menace'}]
# 44  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 49  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 50  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 56  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 60                [{'title': 'Attack of the Clones'}]
# 62  [{'title': 'Attack of the Clones'}, {'title': ...
# 63                [{'title': 'Attack of the Clones'}]
# 65  [{'title': 'Attack of the Clones'}, {'title': ...
# 66  [{'title': 'Attack of the Clones'}, {'title': ...
# 67                [{'title': 'Attack of the Clones'}]
#
#                                species  \
# 0                                   []
# 1    [http://swapi.dev/api/species/2/]
# 2    [http://swapi.dev/api/species/2/]
# 3                                   []
# 4                                   []
# 5                                   []
# 6                                   []
# 8                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 12   [http://swapi.dev/api/species/3/]
# 13                                  []
# 14   [http://swapi.dev/api/species/4/]
# 15   [http://swapi.dev/api/species/5/]
# 16                                  []
# 18   [http://swapi.dev/api/species/6/]
# 19                                  []
# 20                                  []
# 21   [http://swapi.dev/api/species/2/]
# 22   [http://swapi.dev/api/species/7/]
# 23                                  []
# 24                                  []
# 25   [http://swapi.dev/api/species/8/]
# 26                                  []
# 28   [http://swapi.dev/api/species/9/]
# 30                                  []
# 32                                  []
# 33                                  []
# 34  [http://swapi.dev/api/species/12/]
# 40                                  []
# 41                                  []
# 42  [http://swapi.dev/api/species/22/]
# 44  [http://swapi.dev/api/species/15/]
# 49                                  []
# 50  [http://swapi.dev/api/species/20/]
# 56  [http://swapi.dev/api/species/26/]
# 60                                  []
# 62  [http://swapi.dev/api/species/29/]
# 63  [http://swapi.dev/api/species/29/]
# 65   [http://swapi.dev/api/species/1/]
# 66   [http://swapi.dev/api/species/1/]
# 67                                  []
#
#                                              vehicles  \
# 0   [http://swapi.dev/api/vehicles/14/, http://swa...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                 [http://swapi.dev/api/vehicles/30/]
# 5                                                  []
# 6                                                  []
# 8                                                  []
# 9                 [http://swapi.dev/api/vehicles/38/]
# 10  [http://swapi.dev/api/vehicles/44/, http://swa...
# 11                                                 []
# 12                [http://swapi.dev/api/vehicles/19/]
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                [http://swapi.dev/api/vehicles/14/]
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 28                                                 []
# 30                [http://swapi.dev/api/vehicles/38/]
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 40                                                 []
# 41                                                 []
# 42                [http://swapi.dev/api/vehicles/42/]
# 44                                                 []
# 49                                                 []
# 50                                                 []
# 56                                                 []
# 60                                                 []
# 62                                                 []
# 63                                                 []
# 65                [http://swapi.dev/api/vehicles/55/]
# 66                                                 []
# 67                                                 []
#
#                                             starships  \
# 0   [http://swapi.dev/api/starships/12/, http://sw...
# 1                                                  []
# 2                                                  []
# 3                [http://swapi.dev/api/starships/13/]
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 8                [http://swapi.dev/api/starships/12/]
# 9   [http://swapi.dev/api/starships/48/, http://sw...
# 10  [http://swapi.dev/api/starships/39/, http://sw...
# 11                                                 []
# 12  [http://swapi.dev/api/starships/10/, http://sw...
# 13  [http://swapi.dev/api/starships/10/, http://sw...
# 14                                                 []
# 15                                                 []
# 16               [http://swapi.dev/api/starships/12/]
# 18                                                 []
# 19                                                 []
# 20               [http://swapi.dev/api/starships/21/]
# 21                                                 []
# 22                                                 []
# 23               [http://swapi.dev/api/starships/10/]
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 28                                                 []
# 30                                                 []
# 32                                                 []
# 33  [http://swapi.dev/api/starships/39/, http://sw...
# 34                                                 []
# 40                                                 []
# 41                                                 []
# 42               [http://swapi.dev/api/starships/41/]
# 44                                                 []
# 49                                                 []
# 50                                                 []
# 56               [http://swapi.dev/api/starships/48/]
# 60                                                 []
# 62                                                 []
# 63                                                 []
# 65                                                 []
# 66                                                 []
# 67                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5   2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6   2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 8   2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9   2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
# 10  2014-12-10T16:20:44.310000Z  2014-12-20T21:17:50.327000Z
# 11  2014-12-10T16:26:56.138000Z  2014-12-20T21:17:50.330000Z
# 12  2014-12-10T16:42:45.066000Z  2014-12-20T21:17:50.332000Z
# 13  2014-12-10T16:49:14.582000Z  2014-12-20T21:17:50.334000Z
# 14  2014-12-10T17:03:30.334000Z  2014-12-20T21:17:50.336000Z
# 15  2014-12-10T17:11:31.638000Z  2014-12-20T21:17:50.338000Z
# 16  2014-12-12T11:08:06.469000Z  2014-12-20T21:17:50.341000Z
# 18  2014-12-15T12:26:01.042000Z  2014-12-20T21:17:50.345000Z
# 19  2014-12-15T12:48:05.971000Z  2014-12-20T21:17:50.347000Z
# 20  2014-12-15T12:49:32.457000Z  2014-12-20T21:17:50.349000Z
# 21  2014-12-15T12:51:10.076000Z  2014-12-20T21:17:50.351000Z
# 22  2014-12-15T12:53:49.297000Z  2014-12-20T21:17:50.355000Z
# 23  2014-12-15T12:56:32.683000Z  2014-12-20T21:17:50.357000Z
# 24  2014-12-15T13:01:57.178000Z  2014-12-20T21:17:50.359000Z
# 25  2014-12-18T11:07:50.584000Z  2014-12-20T21:17:50.362000Z
# 26  2014-12-18T11:12:38.895000Z  2014-12-20T21:17:50.364000Z
# 28  2014-12-18T11:21:58.954000Z  2014-12-20T21:17:50.369000Z
# 30  2014-12-19T16:54:53.618000Z  2014-12-20T21:17:50.375000Z
# 32  2014-12-19T17:21:45.915000Z  2014-12-20T21:17:50.379000Z
# 33  2014-12-19T17:28:26.926000Z  2014-12-20T21:17:50.381000Z
# 34  2014-12-19T17:29:32.489000Z  2014-12-20T21:17:50.383000Z
# 40  2014-12-19T17:55:43.348000Z  2014-12-20T21:17:50.399000Z
# 41  2014-12-19T17:57:41.191000Z  2014-12-20T21:17:50.401000Z
# 42  2014-12-19T18:00:41.929000Z  2014-12-20T21:17:50.403000Z
# 44  2014-12-20T09:48:01.172000Z  2014-12-20T21:17:50.409000Z
# 49  2014-12-20T10:12:30.846000Z  2014-12-20T21:17:50.420000Z
# 50  2014-12-20T10:15:32.293000Z  2014-12-20T21:17:50.422000Z
# 56  2014-12-20T10:49:19.859000Z  2014-12-20T21:17:50.439000Z
# 60  2014-12-20T15:59:03.958000Z  2014-12-20T21:17:50.451000Z
# 62  2014-12-20T16:45:53.668000Z  2014-12-20T21:17:50.455000Z
# 63  2014-12-20T16:46:40.440000Z  2014-12-20T21:17:50.457000Z
# 65  2014-12-20T16:52:14.726000Z  2014-12-20T21:17:50.462000Z
# 66  2014-12-20T16:53:08.575000Z  2014-12-20T21:17:50.463000Z
# 67  2014-12-20T16:54:41.620000Z  2014-12-20T21:17:50.465000Z
#
#                                 url
# 0    http://swapi.dev/api/people/1/
# 1    http://swapi.dev/api/people/2/
# 2    http://swapi.dev/api/people/3/
# 3    http://swapi.dev/api/people/4/
# 4    http://swapi.dev/api/people/5/
# 5    http://swapi.dev/api/people/6/
# 6    http://swapi.dev/api/people/7/
# 8    http://swapi.dev/api/people/9/
# 9   http://swapi.dev/api/people/10/
# 10  http://swapi.dev/api/people/11/
# 11  http://swapi.dev/api/people/12/
# 12  http://swapi.dev/api/people/13/
# 13  http://swapi.dev/api/people/14/
# 14  http://swapi.dev/api/people/15/
# 15  http://swapi.dev/api/people/16/
# 16  http://swapi.dev/api/people/18/
# 18  http://swapi.dev/api/people/20/
# 19  http://swapi.dev/api/people/21/
# 20  http://swapi.dev/api/people/22/
# 21  http://swapi.dev/api/people/23/
# 22  http://swapi.dev/api/people/24/
# 23  http://swapi.dev/api/people/25/
# 24  http://swapi.dev/api/people/26/
# 25  http://swapi.dev/api/people/27/
# 26  http://swapi.dev/api/people/28/
# 28  http://swapi.dev/api/people/30/
# 30  http://swapi.dev/api/people/32/
# 32  http://swapi.dev/api/people/34/
# 33  http://swapi.dev/api/people/35/
# 34  http://swapi.dev/api/people/36/
# 40  http://swapi.dev/api/people/42/
# 41  http://swapi.dev/api/people/43/
# 42  http://swapi.dev/api/people/44/
# 44  http://swapi.dev/api/people/46/
# 49  http://swapi.dev/api/people/51/
# 50  http://swapi.dev/api/people/52/
# 56  http://swapi.dev/api/people/58/
# 60  http://swapi.dev/api/people/62/
# 62  http://swapi.dev/api/people/64/
# 63  http://swapi.dev/api/people/65/
# 65  http://swapi.dev/api/people/67/
# 66  http://swapi.dev/api/people/68/
# 67  http://swapi.dev/api/people/69/

# %%
df1['birth_year'] = df1['birth_year'].str.rstrip('BBY')
df1['birth_year'] = pd.to_numeric(df1['birth_year'])
df1
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                      name height     mass     hair_color        skin_color  \
# 0          Luke Skywalker    172       77          blond              fair
# 1                   C-3PO    167       75            n/a              gold
# 2                   R2-D2     96       32            n/a       white, blue
# 3             Darth Vader    202      136           none             white
# 4             Leia Organa    150       49          brown             light
# 5               Owen Lars    178      120    brown, grey             light
# 6      Beru Whitesun lars    165       75          brown             light
# 8       Biggs Darklighter    183       84          black             light
# 9          Obi-Wan Kenobi    182       77  auburn, white              fair
# 10       Anakin Skywalker    188       84          blond              fair
# 11         Wilhuff Tarkin    180  unknown   auburn, grey              fair
# 12              Chewbacca    228      112          brown           unknown
# 13               Han Solo    180       80          brown              fair
# 14                 Greedo    173       74            n/a             green
# 15  Jabba Desilijic Tiure    175    1,358            n/a  green-tan, brown
# 16         Wedge Antilles    170       77          brown              fair
# 18                   Yoda     66       17          white             green
# 19              Palpatine    170       75           grey              pale
# 20              Boba Fett    183     78.2          black              fair
# 21                  IG-88    200      140           none             metal
# 22                  Bossk    190      113           none             green
# 23       Lando Calrissian    177       79          black              dark
# 24                  Lobot    175       79           none             light
# 25                 Ackbar    180       83           none      brown mottle
# 26             Mon Mothma    150  unknown         auburn              fair
# 28  Wicket Systri Warrick     88       20          brown             brown
# 30           Qui-Gon Jinn    193       89          brown              fair
# 32          Finis Valorum    170  unknown          blond              fair
# 33          Padmé Amidala    185       45          brown             light
# 34          Jar Jar Binks    196       66           none            orange
# 40          Quarsh Panaka    183  unknown          black              dark
# 41         Shmi Skywalker    163  unknown          black              fair
# 42             Darth Maul    175       80           none               red
# 44            Ayla Secura    178       55           none              blue
# 49             Mace Windu    188       84           none              dark
# 50           Ki-Adi-Mundi    198       82          white              pale
# 56               Plo Koon    188       80           none            orange
# 60            Cliegg Lars    183  unknown          brown              fair
# 62        Luminara Unduli    170     56.2          black            yellow
# 63          Barriss Offee    166       50          black            yellow
# 65                  Dooku    193       80          white              fair
# 66    Bail Prestor Organa    191  unknown          black               tan
# 67             Jango Fett    183       79          black               tan
#
#     eye_color  birth_year         gender                         homeworld  \
# 0        blue        19.0           male   http://swapi.dev/api/planets/1/
# 1      yellow       112.0            n/a   http://swapi.dev/api/planets/1/
# 2         red        33.0            n/a   http://swapi.dev/api/planets/8/
# 3      yellow        41.9           male   http://swapi.dev/api/planets/1/
# 4       brown        19.0         female   http://swapi.dev/api/planets/2/
# 5        blue        52.0           male   http://swapi.dev/api/planets/1/
# 6        blue        47.0         female   http://swapi.dev/api/planets/1/
# 8       brown        24.0           male   http://swapi.dev/api/planets/1/
# 9   blue-gray        57.0           male  http://swapi.dev/api/planets/20/
# 10       blue        41.9           male   http://swapi.dev/api/planets/1/
# 11       blue        64.0           male  http://swapi.dev/api/planets/21/
# 12       blue       200.0           male  http://swapi.dev/api/planets/14/
# 13      brown        29.0           male  http://swapi.dev/api/planets/22/
# 14      black        44.0           male  http://swapi.dev/api/planets/23/
# 15     orange       600.0  hermaphrodite  http://swapi.dev/api/planets/24/
# 16      hazel        21.0           male  http://swapi.dev/api/planets/22/
# 18      brown       896.0           male  http://swapi.dev/api/planets/28/
# 19     yellow        82.0           male   http://swapi.dev/api/planets/8/
# 20      brown        31.5           male  http://swapi.dev/api/planets/10/
# 21        red        15.0           none  http://swapi.dev/api/planets/28/
# 22        red        53.0           male  http://swapi.dev/api/planets/29/
# 23      brown        31.0           male  http://swapi.dev/api/planets/30/
# 24       blue        37.0           male   http://swapi.dev/api/planets/6/
# 25     orange        41.0           male  http://swapi.dev/api/planets/31/
# 26       blue        48.0         female  http://swapi.dev/api/planets/32/
# 28      brown         8.0           male   http://swapi.dev/api/planets/7/
# 30       blue        92.0           male  http://swapi.dev/api/planets/28/
# 32       blue        91.0           male   http://swapi.dev/api/planets/9/
# 33      brown        46.0         female   http://swapi.dev/api/planets/8/
# 34     orange        52.0           male   http://swapi.dev/api/planets/8/
# 40      brown        62.0           male   http://swapi.dev/api/planets/8/
# 41      brown        72.0         female   http://swapi.dev/api/planets/1/
# 42     yellow        54.0           male  http://swapi.dev/api/planets/36/
# 44      hazel        48.0         female  http://swapi.dev/api/planets/37/
# 49      brown        72.0           male  http://swapi.dev/api/planets/42/
# 50     yellow        92.0           male  http://swapi.dev/api/planets/43/
# 56      black        22.0           male  http://swapi.dev/api/planets/49/
# 60       blue        82.0           male   http://swapi.dev/api/planets/1/
# 62       blue        58.0         female  http://swapi.dev/api/planets/51/
# 63       blue        40.0         female  http://swapi.dev/api/planets/51/
# 65      brown       102.0           male  http://swapi.dev/api/planets/52/
# 66      brown        67.0           male   http://swapi.dev/api/planets/2/
# 67      brown        66.0           male  http://swapi.dev/api/planets/53/
#
#                                                 films  \
# 0   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 1   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 2   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 3   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 4   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 5   [{'title': 'A New Hope'}, {'title': 'Attack of...
# 6   [{'title': 'A New Hope'}, {'title': 'Attack of...
# 8                           [{'title': 'A New Hope'}]
# 9   [{'title': 'A New Hope'}, {'title': 'The Empir...
# 10  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 11  [{'title': 'A New Hope'}, {'title': 'Revenge o...
# 12  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 13  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 14                          [{'title': 'A New Hope'}]
# 15  [{'title': 'A New Hope'}, {'title': 'Return of...
# 16  [{'title': 'A New Hope'}, {'title': 'The Empir...
# 18  [{'title': 'The Empire Strikes Back'}, {'title...
# 19  [{'title': 'The Empire Strikes Back'}, {'title...
# 20  [{'title': 'The Empire Strikes Back'}, {'title...
# 21             [{'title': 'The Empire Strikes Back'}]
# 22             [{'title': 'The Empire Strikes Back'}]
# 23  [{'title': 'The Empire Strikes Back'}, {'title...
# 24             [{'title': 'The Empire Strikes Back'}]
# 25                  [{'title': 'Return of the Jedi'}]
# 26                  [{'title': 'Return of the Jedi'}]
# 28                  [{'title': 'Return of the Jedi'}]
# 30                  [{'title': 'The Phantom Menace'}]
# 32                  [{'title': 'The Phantom Menace'}]
# 33  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 34  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 40                  [{'title': 'The Phantom Menace'}]
# 41  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 42                  [{'title': 'The Phantom Menace'}]
# 44  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 49  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 50  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 56  [{'title': 'The Phantom Menace'}, {'title': 'A...
# 60                [{'title': 'Attack of the Clones'}]
# 62  [{'title': 'Attack of the Clones'}, {'title': ...
# 63                [{'title': 'Attack of the Clones'}]
# 65  [{'title': 'Attack of the Clones'}, {'title': ...
# 66  [{'title': 'Attack of the Clones'}, {'title': ...
# 67                [{'title': 'Attack of the Clones'}]
#
#                                species  \
# 0                                   []
# 1    [http://swapi.dev/api/species/2/]
# 2    [http://swapi.dev/api/species/2/]
# 3                                   []
# 4                                   []
# 5                                   []
# 6                                   []
# 8                                   []
# 9                                   []
# 10                                  []
# 11                                  []
# 12   [http://swapi.dev/api/species/3/]
# 13                                  []
# 14   [http://swapi.dev/api/species/4/]
# 15   [http://swapi.dev/api/species/5/]
# 16                                  []
# 18   [http://swapi.dev/api/species/6/]
# 19                                  []
# 20                                  []
# 21   [http://swapi.dev/api/species/2/]
# 22   [http://swapi.dev/api/species/7/]
# 23                                  []
# 24                                  []
# 25   [http://swapi.dev/api/species/8/]
# 26                                  []
# 28   [http://swapi.dev/api/species/9/]
# 30                                  []
# 32                                  []
# 33                                  []
# 34  [http://swapi.dev/api/species/12/]
# 40                                  []
# 41                                  []
# 42  [http://swapi.dev/api/species/22/]
# 44  [http://swapi.dev/api/species/15/]
# 49                                  []
# 50  [http://swapi.dev/api/species/20/]
# 56  [http://swapi.dev/api/species/26/]
# 60                                  []
# 62  [http://swapi.dev/api/species/29/]
# 63  [http://swapi.dev/api/species/29/]
# 65   [http://swapi.dev/api/species/1/]
# 66   [http://swapi.dev/api/species/1/]
# 67                                  []
#
#                                              vehicles  \
# 0   [http://swapi.dev/api/vehicles/14/, http://swa...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                 [http://swapi.dev/api/vehicles/30/]
# 5                                                  []
# 6                                                  []
# 8                                                  []
# 9                 [http://swapi.dev/api/vehicles/38/]
# 10  [http://swapi.dev/api/vehicles/44/, http://swa...
# 11                                                 []
# 12                [http://swapi.dev/api/vehicles/19/]
# 13                                                 []
# 14                                                 []
# 15                                                 []
# 16                [http://swapi.dev/api/vehicles/14/]
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 28                                                 []
# 30                [http://swapi.dev/api/vehicles/38/]
# 32                                                 []
# 33                                                 []
# 34                                                 []
# 40                                                 []
# 41                                                 []
# 42                [http://swapi.dev/api/vehicles/42/]
# 44                                                 []
# 49                                                 []
# 50                                                 []
# 56                                                 []
# 60                                                 []
# 62                                                 []
# 63                                                 []
# 65                [http://swapi.dev/api/vehicles/55/]
# 66                                                 []
# 67                                                 []
#
#                                             starships  \
# 0   [http://swapi.dev/api/starships/12/, http://sw...
# 1                                                  []
# 2                                                  []
# 3                [http://swapi.dev/api/starships/13/]
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 8                [http://swapi.dev/api/starships/12/]
# 9   [http://swapi.dev/api/starships/48/, http://sw...
# 10  [http://swapi.dev/api/starships/39/, http://sw...
# 11                                                 []
# 12  [http://swapi.dev/api/starships/10/, http://sw...
# 13  [http://swapi.dev/api/starships/10/, http://sw...
# 14                                                 []
# 15                                                 []
# 16               [http://swapi.dev/api/starships/12/]
# 18                                                 []
# 19                                                 []
# 20               [http://swapi.dev/api/starships/21/]
# 21                                                 []
# 22                                                 []
# 23               [http://swapi.dev/api/starships/10/]
# 24                                                 []
# 25                                                 []
# 26                                                 []
# 28                                                 []
# 30                                                 []
# 32                                                 []
# 33  [http://swapi.dev/api/starships/39/, http://sw...
# 34                                                 []
# 40                                                 []
# 41                                                 []
# 42               [http://swapi.dev/api/starships/41/]
# 44                                                 []
# 49                                                 []
# 50                                                 []
# 56               [http://swapi.dev/api/starships/48/]
# 60                                                 []
# 62                                                 []
# 63                                                 []
# 65                                                 []
# 66                                                 []
# 67                                                 []
#
#                         created                       edited  \
# 0   2014-12-09T13:50:51.644000Z  2014-12-20T21:17:56.891000Z
# 1   2014-12-10T15:10:51.357000Z  2014-12-20T21:17:50.309000Z
# 2   2014-12-10T15:11:50.376000Z  2014-12-20T21:17:50.311000Z
# 3   2014-12-10T15:18:20.704000Z  2014-12-20T21:17:50.313000Z
# 4   2014-12-10T15:20:09.791000Z  2014-12-20T21:17:50.315000Z
# 5   2014-12-10T15:52:14.024000Z  2014-12-20T21:17:50.317000Z
# 6   2014-12-10T15:53:41.121000Z  2014-12-20T21:17:50.319000Z
# 8   2014-12-10T15:59:50.509000Z  2014-12-20T21:17:50.323000Z
# 9   2014-12-10T16:16:29.192000Z  2014-12-20T21:17:50.325000Z
# 10  2014-12-10T16:20:44.310000Z  2014-12-20T21:17:50.327000Z
# 11  2014-12-10T16:26:56.138000Z  2014-12-20T21:17:50.330000Z
# 12  2014-12-10T16:42:45.066000Z  2014-12-20T21:17:50.332000Z
# 13  2014-12-10T16:49:14.582000Z  2014-12-20T21:17:50.334000Z
# 14  2014-12-10T17:03:30.334000Z  2014-12-20T21:17:50.336000Z
# 15  2014-12-10T17:11:31.638000Z  2014-12-20T21:17:50.338000Z
# 16  2014-12-12T11:08:06.469000Z  2014-12-20T21:17:50.341000Z
# 18  2014-12-15T12:26:01.042000Z  2014-12-20T21:17:50.345000Z
# 19  2014-12-15T12:48:05.971000Z  2014-12-20T21:17:50.347000Z
# 20  2014-12-15T12:49:32.457000Z  2014-12-20T21:17:50.349000Z
# 21  2014-12-15T12:51:10.076000Z  2014-12-20T21:17:50.351000Z
# 22  2014-12-15T12:53:49.297000Z  2014-12-20T21:17:50.355000Z
# 23  2014-12-15T12:56:32.683000Z  2014-12-20T21:17:50.357000Z
# 24  2014-12-15T13:01:57.178000Z  2014-12-20T21:17:50.359000Z
# 25  2014-12-18T11:07:50.584000Z  2014-12-20T21:17:50.362000Z
# 26  2014-12-18T11:12:38.895000Z  2014-12-20T21:17:50.364000Z
# 28  2014-12-18T11:21:58.954000Z  2014-12-20T21:17:50.369000Z
# 30  2014-12-19T16:54:53.618000Z  2014-12-20T21:17:50.375000Z
# 32  2014-12-19T17:21:45.915000Z  2014-12-20T21:17:50.379000Z
# 33  2014-12-19T17:28:26.926000Z  2014-12-20T21:17:50.381000Z
# 34  2014-12-19T17:29:32.489000Z  2014-12-20T21:17:50.383000Z
# 40  2014-12-19T17:55:43.348000Z  2014-12-20T21:17:50.399000Z
# 41  2014-12-19T17:57:41.191000Z  2014-12-20T21:17:50.401000Z
# 42  2014-12-19T18:00:41.929000Z  2014-12-20T21:17:50.403000Z
# 44  2014-12-20T09:48:01.172000Z  2014-12-20T21:17:50.409000Z
# 49  2014-12-20T10:12:30.846000Z  2014-12-20T21:17:50.420000Z
# 50  2014-12-20T10:15:32.293000Z  2014-12-20T21:17:50.422000Z
# 56  2014-12-20T10:49:19.859000Z  2014-12-20T21:17:50.439000Z
# 60  2014-12-20T15:59:03.958000Z  2014-12-20T21:17:50.451000Z
# 62  2014-12-20T16:45:53.668000Z  2014-12-20T21:17:50.455000Z
# 63  2014-12-20T16:46:40.440000Z  2014-12-20T21:17:50.457000Z
# 65  2014-12-20T16:52:14.726000Z  2014-12-20T21:17:50.462000Z
# 66  2014-12-20T16:53:08.575000Z  2014-12-20T21:17:50.463000Z
# 67  2014-12-20T16:54:41.620000Z  2014-12-20T21:17:50.465000Z
#
#                                 url
# 0    http://swapi.dev/api/people/1/
# 1    http://swapi.dev/api/people/2/
# 2    http://swapi.dev/api/people/3/
# 3    http://swapi.dev/api/people/4/
# 4    http://swapi.dev/api/people/5/
# 5    http://swapi.dev/api/people/6/
# 6    http://swapi.dev/api/people/7/
# 8    http://swapi.dev/api/people/9/
# 9   http://swapi.dev/api/people/10/
# 10  http://swapi.dev/api/people/11/
# 11  http://swapi.dev/api/people/12/
# 12  http://swapi.dev/api/people/13/
# 13  http://swapi.dev/api/people/14/
# 14  http://swapi.dev/api/people/15/
# 15  http://swapi.dev/api/people/16/
# 16  http://swapi.dev/api/people/18/
# 18  http://swapi.dev/api/people/20/
# 19  http://swapi.dev/api/people/21/
# 20  http://swapi.dev/api/people/22/
# 21  http://swapi.dev/api/people/23/
# 22  http://swapi.dev/api/people/24/
# 23  http://swapi.dev/api/people/25/
# 24  http://swapi.dev/api/people/26/
# 25  http://swapi.dev/api/people/27/
# 26  http://swapi.dev/api/people/28/
# 28  http://swapi.dev/api/people/30/
# 30  http://swapi.dev/api/people/32/
# 32  http://swapi.dev/api/people/34/
# 33  http://swapi.dev/api/people/35/
# 34  http://swapi.dev/api/people/36/
# 40  http://swapi.dev/api/people/42/
# 41  http://swapi.dev/api/people/43/
# 42  http://swapi.dev/api/people/44/
# 44  http://swapi.dev/api/people/46/
# 49  http://swapi.dev/api/people/51/
# 50  http://swapi.dev/api/people/52/
# 56  http://swapi.dev/api/people/58/
# 60  http://swapi.dev/api/people/62/
# 62  http://swapi.dev/api/people/64/
# 63  http://swapi.dev/api/people/65/
# 65  http://swapi.dev/api/people/67/
# 66  http://swapi.dev/api/people/68/
# 67  http://swapi.dev/api/people/69/

# %%
df1.loc[df1['birth_year'].idxmax()]['name']
# Out:
# 'Yoda'

# %%
df1.loc[df1['birth_year'].idxmax()]
# Out:
# name                                                       Yoda
# height                                                       66
# mass                                                         17
# hair_color                                                white
# skin_color                                                green
# eye_color                                                 brown
# birth_year                                                  896
# gender                                                     male
# homeworld                      http://swapi.dev/api/planets/28/
# films         [{'title': 'The Empire Strikes Back'}, {'title...
# species                       [http://swapi.dev/api/species/6/]
# vehicles                                                     []
# starships                                                    []
# created                             2014-12-15T12:26:01.042000Z
# edited                              2014-12-20T21:17:50.345000Z
# url                             http://swapi.dev/api/people/20/
# Name: 18, dtype: object

# %% [markdown]
# **Thus, the name of the oldest person (alien) is _Yoda_ and list the titles of all the films they appeared in is:**

# %%
df1.loc[df1['birth_year'].idxmax()]['films']
# Out:
# [{'title': 'The Empire Strikes Back'},
#  {'title': 'Return of the Jedi'},
#  {'title': 'The Phantom Menace'},
#  {'title': 'Attack of the Clones'},
#  {'title': 'Revenge of the Sith'}]
